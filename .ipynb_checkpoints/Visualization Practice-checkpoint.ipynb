# %% [markdown]
# # Example of Visualizing Data
#  Generate synthetic data for visualization practice

# %%
import numpy as np
import seaborn
import pandas as pd
import matplotlib.pyplot as plt

# %%
#load nba statistics as csv and create dataframe
data = pd.read_csv('/home/colinphillips17/Downloads/sportsref_download.csv', header = 1)
data.head()
# Out:
#    Rk   Season   Lg   Age   Ht     Wt     G     MP    FG   FGA  ...    PTS  \
# 0   1  2019-20  NBA  26.1  6-6  216.0   547  241.6  40.4  88.9  ...  110.4
# 1   2  2018-19  NBA  26.3  6-6  217.0  1230  241.6  41.1  89.2  ...  111.2
# 2   3  2017-18  NBA  26.4  6-7  219.0  1230  241.4  39.6  86.1  ...  106.3
# 3   4  2016-17  NBA  26.6  6-7  220.0  1230  241.6  39.0  85.4  ...  105.6
# 4   5  2015-16  NBA  26.7  6-7  221.0  1230  241.8  38.2  84.6  ...  102.7
#
#      FG%    3P%    FT%   Pace   eFG%  TOV%  ORB%  FT/FGA   ORtg
# 0  0.455  0.355  0.770  100.4  0.522  13.0  22.7   0.198  109.3
# 1  0.461  0.355  0.766  100.0  0.524  12.4  22.9   0.198  110.4
# 2  0.460  0.362  0.767   97.3  0.521  13.0  22.3   0.193  108.6
# 3  0.457  0.358  0.772   96.4  0.514  12.7  23.3   0.209  108.8
# 4  0.452  0.354  0.757   95.8  0.502  13.2  23.8   0.209  106.4
#
# [5 rows x 32 columns]

# %%
#sort data from earliest to latest
data = data.sort_values("Season",ascending = True)

# %%
#create line graph of fg% across time
data["Season"] = data["Season"].str.slice(0,-3)
data["Season"] = pd.to_numeric(data["Season"],errors="coerce")

# %%
seaborn.lineplot(x="Season",y="FG%",data = data)

# %%
seaborn.lmplot(
    x='Season', 
    y='Age', 
    data=data, 
    ci=False, 
);

# %%
seaborn.scatterplot(x="FGA",y="FG%",data = data)

# %%
seaborn.scatterplot(x="Wt",y="3P%",data=data)

# %%
fig, axs = plt.subplots(ncols=3,figsize = (20,10))
seaborn.lineplot(x='Season', y='Age', data=data, ax=axs[0])
seaborn.lineplot(x='Season', y='Pace', data=data, ax=axs[1])
seaborn.lineplot(x='Season',y='PTS', data=data, ax=axs[2])
axs
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa91ab1da90>,
# ...
#       dtype=object)

# %%
seaborn.pairplot(data)
