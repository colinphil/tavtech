# %%
import pandas as pd
import numpy as np
import random
import sys
import csv

# %%
latitude = -11.2821
longitude = 24.645

# %%
df = pd.read_csv("twittersentiment2020.csv")
df[["Tweets","Dates","Sentiment"]]
# Out:
#                                                 Tweets       Dates Sentiment
# 0    It was great to host our colleagues from @EC_S...  2020-01-16   neutral
# 1    #phep #globalhealth #Ebola #smem https://t.co/...  2020-01-16  positive
# 2    #Ebola in #DRC . Cases traced to Mabalako stil...  2020-01-16   neutral
# 3    My first opinion piece for 2020 is for Project...  2020-01-16   neutral
# 4    Ease of movement in #DRC allows people to put ...  2020-01-16   neutral
# ..                                                 ...         ...       ...
# 840  A must read story from @HelenBranswell of how ...  2020-01-08       NaN
# 841  The inside story on the creations of the Ebola...  2020-01-08       NaN
# 842  “#Measles has killed nearly three times as man...  2020-01-08       NaN
# 843  .@USAIDMarkGreen &amp; @DrTedros ont convenu q...  2020-01-08       NaN
# 844  Cuando parecía que el #ebola dejaba de ser not...  2020-01-08       NaN
#
# [845 rows x 3 columns]

# %%
location = pd.DataFrame({'Latitude': np.random.randn(1000), \
                   'Longitude': np.random.randn(1000)})
df["Latitude"] = location["Latitude"]*1+10.000
df["Longitude"]= location["Longitude"]*5+4.356
df.to_csv("twittersentiment2020_v4.csv")
df
# Out:
#      Unnamed: 0                                             Tweets  \
# 0             0  It was great to host our colleagues from @EC_S...
# 1             1  #phep #globalhealth #Ebola #smem https://t.co/...
# 2             2  #Ebola in #DRC . Cases traced to Mabalako stil...
# 3             3  My first opinion piece for 2020 is for Project...
# 4             4  Ease of movement in #DRC allows people to put ...
# ..          ...                                                ...
# 840         840  A must read story from @HelenBranswell of how ...
# 841         841  The inside story on the creations of the Ebola...
# 842         842  “#Measles has killed nearly three times as man...
# 843         843  .@USAIDMarkGreen &amp; @DrTedros ont convenu q...
# 844         844  Cuando parecía que el #ebola dejaba de ser not...
#
#           Dates  Longitude   Latitude Sentiment
# 0    2020-01-16   4.334394  11.970804   neutral
# 1    2020-01-16  -7.828624  10.650561  positive
# ...
