# %% [markdown]
# # Seaborn
# [seaborn official](https://seaborn.pydata.org)
#
# Seaborn does not have a logo 👎. Which is surprising since it deals with visualization.
#
# <img src="https://media.giphy.com/media/CfbDPJ17xZwqI/giphy.gif" width='300'>

# %% [markdown]
# While matplotlib is a great visulaization tool, it is a pretty old one. And nowdays it lacks a more aesthetic flavor and  a quicker interface into interacting with the `pandas` module, and specifically the DataFrame object. This is where the `seaborn` module blossom.
# We start of by importing our relevant modules, seaborn is usually aliased `sns`

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Pandas Interface
# One of the coolest features in seaborn is the fact that we can pass a dataframe and then choose the columns to be our x, y values. We will now explore this with some of the more common plots out there.

# %%
df = pd.DataFrame({
    'quarter' : [0, 1, 2, 0, 1, 2],
    'earnings' : [2, 85, 325, 80, 47, 1],
    'company' : ['G', 'G', 'G', 'B', 'B', 'B']
})

df.head()
# Out:
#    quarter  earnings company
# 0        0         2       G
# 1        1        85       G
# 2        2       325       G
# 3        0        80       B
# 4        1        47       B

# %% [markdown]
# ## Lineplot
# We first take a look at the `seaborn` line plot which is very good for trend searching. It is very useful when trying to analyze time series data which unfortunately we won't have time to go into.
# Notice how the `hue` parameters acts as a groupby mechanism.

# %%
sns.lineplot(x='quarter', y='earnings', hue='company', data=df)

# %% [markdown]
# ### Exercise
# Exhibit the same graph as above using pandas and pyplot.

# %%
# your code here
lines = df.plot.line(x = "quarter",y = "earnings",subplots = True)

# %% [markdown]
# Load the __mpg__ dataset from seaborn and display the horsepower as a function of the year. plot each origin separately.

# %%
df = sns.load_dataset('mpg') # This one is on the house but the rest will be up to you.
# Your code here
sns.lmplot(x = "model_year",y="horsepower", data = df)

# %% [markdown]
# ## Scatter plots

# %%
df = pd.DataFrame({
    'x' : [0, 1, 2, 3, 4, 5],
    'y' : [11, 14, 17, 19, 20, 21],
    'size' : [100, 200, 300, 400, 500, 600],
    'color' : [10, 10, 20, 20, 20, 20]
})

df.head()
# Out:
#    x   y  size  color
# 0  0  11   100     10
# 1  1  14   200     10
# 2  2  17   300     20
# 3  3  19   400     20
# 4  4  20   500     20

# %% [markdown]
# In the scatter plot we can choose a column which serves as the size of each point.

# %%
sns.scatterplot(x='x', y='y', size='size', data=df)

# %% [markdown]
# And we can also set a color for each point.

# %%
sns.scatterplot(x='x', y='y', size='size', hue='color', data=df)

# %% [markdown]
# ***
# ## Exercise
# ***
# Load the __car_crashes__ dataset and create a scatter plot with _speeding_ as the x axis,  _alcohol_ as the y axis and the size of the points according to the _total_ column.

# %%
# Your code here
data = sns.load_dataset("car_crashes")
sns.scatterplot(x = 'speeding',y='alcohol',size = "total", data= data)

# %% [markdown]
# ## Bar plots
# Very similar to what we just saw, we can easily create informative bar graph using seaborn

# %%
np.random.seed(2612)
df = pd.DataFrame({
    'day' : ['S', 'S', 'S', 'S', 'M', 'M', 'M', 'M', 'T', 'T', 'T', 'T'],
    'km'  : np.random.randint(low=30, high=100, size=(12)),
    'car' : ['kia', 'mazda'] * 6
    
})

# %%
df
# Out:
#    day  km    car
# 0    S  62    kia
# 1    S  83  mazda
# 2    S  52    kia
# 3    S  63  mazda
# 4    M  83    kia
# 5    M  83  mazda
# 6    M  98    kia
# 7    M  89  mazda
# 8    T  43    kia
# 9    T  46  mazda
# 10   T  79    kia
# 11   T  75  mazda

# %%
sns.barplot(x='day', y='km', hue='car', data=df)

# %% [markdown]
# ## Exercise
# Load the __titanic__ dataset and see plot a bar graph of the count of survivers grouped by _class_. You'll need to use a different method from `barplot`.

# %%
# Your code here
titanic = sns.load_dataset("titanic")
sns.countplot(x="class",hue="survived",data=titanic)

# %% [markdown]
# This gives us the mean value of each car for each day.

# %% [markdown]
# ## distplot
# The seaborn distplot method combines matplotlib hist function, with a smart binning pick and a kde fit. But it works on series rather then DataFrames.

# %%
values = np.random.randn(1000) * 10
sns.distplot(values)

# %% [markdown]
# But, If we want to get fancier we can use seaborn FacetGrid. We will not dive into this topic, what the facet grid does is grouping

# %%
# Load the tips dataset.
tips = sns.load_dataset("tips")

# Create a fcaet grid, creating the following groups:
g = sns.FacetGrid(tips, row="sex", col="time", margin_titles=True)
bins = np.linspace(0, 60, 13)

# Show how the total_bill values behave in each group.
g.map(sns.distplot, "total_bill", bins=bins)

# %% [markdown]
# ## Pair-plot
# A great function for quickly visualizing a classification dataset is by using seaborn pair plot. This plot will gave a scatter plot of every possible combination of numeric variable along side each variable "distribution".

# %%
iris = sns.load_dataset('iris')
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris, hue='species')

# %% [markdown]
# So what did we get back?
# A scatter plot of each 2 variables, and the diagonal is the distribution of that variable under each class

# %% [markdown]
# There are many more functionalities that seaborn offer. I highly recommend visiting the [official API page](https://seaborn.pydata.org/api.html) of seaborn, where you can quickly see every thing that seaborn has to offer.

# %% [markdown]
# # Colophon
# This notebook was written by __Yoav Orlev__ and is part of the __intro to Python for data science__ course at IDC Herzliya.
#
# This work is licensed under a CC BY-NC-SA 4.0 International License.

# %% [markdown]
# ![Python logo](https://www.python.org/static/community_logos/python-logo.png)
