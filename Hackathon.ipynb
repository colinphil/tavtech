# %%
import pandas as pd 
import numpy as np

# %%
import random
import sys
import math
import csv

#long,lat of Central Africa
latitude = 13.53
longitude = 2.46


df = pd.DataFrame({'Lat': np.random.uniform(-3, 3, 1001), \
                   'Long':np.random.uniform(-3,3, 1001)})
#print(df['A'] + latitude)

df['Lat'] =  df['Lat'] + latitude
df['Long'] =  df['Long'] + longitude
df_csvFile = pd.read_csv('/home/colinphillips17/Downloads/Ebola_1K_Sample_Nov12_2014 - Sheet 1.csv')

df_csvFile['Lat'] = df['Lat']
df_csvFile['Long'] = df['Long']

newData = df_csvFile[["title","Lat","Long"]]
# Out:
#                                                  title        Lat      Long
# 0    Administration makes case for emergency Ebola ...  12.876304  0.232360
# 1    RT @UmaruFofana: #SierraLeone confirms 94 new ...  14.621528  3.842608
# 2    Who will pay to stop Ebola?   http://t.co/hOeA...  14.238729  3.715895
# 3    Administration makes case for emergency Ebola ...  15.552209  3.573954
# 4    RT @UmaruFofana: #SierraLeone confirms 94 new ...  13.346283  2.769126
# ..                                                 ...        ...       ...
# 995  First Outbreak Quashed, #Ebola Reappears in Ma...  16.297495  5.158561
# 996  United Nations News Centre - #WestAfrica ‘on b...  15.659375  0.013573
# 997  RT @natlawreview: HHS Issues Bulletin on HIPAA...  12.603656  0.004678
# 998  RT @TackleEbola: Great read by @eklib on Faceb...  14.989542  3.600036
# 999  RT @WhySharksMatter: I mean, sure, he\'s dying...  11.079557 -0.422940
#
# [1000 rows x 3 columns]

# %%
import random
import time

def str_time_prop(start, end, format, prop):
    """Get a time at a proportion of a range of two formatted times.

    start and end should be strings specifying times formated in the
    given format (strftime-style), giving an interval [start, end].
    prop specifies how a proportion of the interval to be taken after
    start.  The returned time will be in the specified format.
    """

    stime = time.mktime(time.strptime(start, format))
    etime = time.mktime(time.strptime(end, format))

    ptime = stime + prop * (etime - stime)

    return time.strftime(format, time.localtime(ptime))


def random_date(start, end, prop):
    return str_time_prop(start, end, '%m/%d/%Y %I:%M %p', prop)

timeStamp = []
for i in range(1000):
    timeStamp.append(random_date("1/8/2014 1:30 PM", "1/10/2014 4:50 AM", random.random()))
timeStamp
# Out:
# ['01/09/2014 02:43 PM',
#  '01/10/2014 03:03 AM',
#  '01/10/2014 12:01 AM',
#  '01/10/2014 12:28 AM',
#  '01/09/2014 10:07 PM',
#  '01/09/2014 07:04 AM',
#  '01/09/2014 07:49 PM',
#  '01/10/2014 03:50 AM',
#  '01/09/2014 05:06 PM',
#  '01/08/2014 07:38 PM',
#  '01/08/2014 05:46 PM',
#  '01/08/2014 01:57 PM',
#  '01/09/2014 11:30 AM',
#  '01/09/2014 05:55 AM',
#  '01/10/2014 04:32 AM',
#  '01/09/2014 01:39 PM',
#  '01/10/2014 04:10 AM',
#  '01/09/2014 10:49 AM',
#  '01/09/2014 08:14 PM',
#  '01/09/2014 03:01 PM',
#  '01/08/2014 10:46 PM',
#  '01/09/2014 01:44 PM',
#  '01/08/2014 09:14 PM',
#  '01/09/2014 07:57 PM',
#  '01/10/2014 03:25 AM',
#  '01/09/2014 08:36 AM',
#  '01/09/2014 06:01 PM',
#  '01/09/2014 03:04 AM',
#  '01/09/2014 03:04 PM',
#  '01/09/2014 11:39 AM',
#  '01/10/2014 01:43 AM',
#  '01/10/2014 01:44 AM',
#  '01/09/2014 12:45 AM',
#  '01/09/2014 10:44 AM',
#  '01/08/2014 02:44 PM',
#  '01/08/2014 08:19 PM',
#  '01/09/2014 07:17 PM',
#  '01/08/2014 06:05 PM',
# ...

# %%
newData["Date"] = timeStamp
# Out:
# /home/colinphillips17/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
newData
# Out:
#                                                  title        Lat      Long  \
# 0    Administration makes case for emergency Ebola ...  12.876304  0.232360
# 1    RT @UmaruFofana: #SierraLeone confirms 94 new ...  14.621528  3.842608
# 2    Who will pay to stop Ebola?   http://t.co/hOeA...  14.238729  3.715895
# 3    Administration makes case for emergency Ebola ...  15.552209  3.573954
# 4    RT @UmaruFofana: #SierraLeone confirms 94 new ...  13.346283  2.769126
# ..                                                 ...        ...       ...
# 995  First Outbreak Quashed, #Ebola Reappears in Ma...  16.297495  5.158561
# 996  United Nations News Centre - #WestAfrica ‘on b...  15.659375  0.013573
# 997  RT @natlawreview: HHS Issues Bulletin on HIPAA...  12.603656  0.004678
# 998  RT @TackleEbola: Great read by @eklib on Faceb...  14.989542  3.600036
# 999  RT @WhySharksMatter: I mean, sure, he\'s dying...  11.079557 -0.422940
#
#                     Date
# 0    01/09/2014 02:43 PM
# ...

# %%
export_csv = newData.to_csv (r'twitterdata.csv', index = None, header=True)
